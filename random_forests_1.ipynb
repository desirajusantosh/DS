# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/desirajusantosh/DS/blob/master/random_forests_1.ipynb)

# %% [markdown]
# Random Forests

# %%
# %load_ext autoreload

# %%
autoreload 2

# %%
# %matplotlib inline

# %%
# !pip install fastai
from fastai.imports import *
# Out:
# ...
#     100% |████████████████████████████████| 122kB 5.3MB/s
# ...
#     100% |████████████████████████████████| 3.6MB 928kB/s
# ...
#     100% |████████████████████████████████| 2.2MB 1.3MB/s
# ...
#     100% |████████████████████████████████| 184kB 12.7MB/s
# ...
#     100% |████████████████████████████████| 1.5MB 13.2MB/s
# ...
#     100% |████████████████████████████████| 112kB 28.8MB/s
# ...
#     100% |████████████████████████████████| 496.4MB 30kB/s
# ...
#     100% |████████████████████████████████| 51kB 18.5MB/s
# ...
#     100% |████████████████████████████████| 61kB 22.7MB/s
# ...
#     100% |████████████████████████████████| 901kB 4.9MB/s
# ...
#     100% |████████████████████████████████| 71kB 25.5MB/s
# ...
#     100% |████████████████████████████████| 11.6MB 715kB/s
# ...
#     100% |████████████████████████████████| 112kB 30.8MB/s
# ...
#     100% |████████████████████████████████| 92kB 31.0MB/s
# ...
#     100% |████████████████████████████████| 15.8MB 2.6MB/s
# ...
#     100% |████████████████████████████████| 1.5MB 7.7MB/s
# ...

# %%
from fastai.imports import *

# %%
from fastai.structured import *

# %%
from pandas_summary import DataFrameSummary

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# %%
from IPython.display import display

# %%
from sklearn import metrics

# %%
# !kaggle competitions download -c bluebook-for-bulldozers
# Out:
# /bin/bash: kaggle: command not found

# %%
# !pip install git+https://github.com/floydwch/kaggle-cli.git
# Out:
# ...
#   Cloning https://github.com/floydwch/kaggle-cli.git to /tmp/pip-req-build-hw76zlfw
# ...
#     100% |████████████████████████████████| 81kB 4.6MB/s
# ...
#     100% |████████████████████████████████| 5.3MB 4.5MB/s
# ...
#     100% |████████████████████████████████| 102kB 24.9MB/s
# ...
#     100% |████████████████████████████████| 81kB 24.3MB/s
# ...
# done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5dudrw8m/wheels/c2/d0/54/64709fb6e7766205e35b5f27e0ecd63a7ae179cadd44d14845
# done
#   Stored in directory: /root/.cache/pip/wheels/02/22/09/66f8c243f9c68dee7e6456a0fd6c117439a64394fdaf02d965
# done
#   Stored in directory: /root/.cache/pip/wheels/a3/61/79/424ef897a2f3b14684a7de5d89e8600b460b89663e6ce9d17c
# done
#   Stored in directory: /root/.cache/pip/wheels/80/34/1c/3967380d9676d162cb59513bd9dc862d0584e045a162095606
# done
#   Stored in directory: /root/.cache/pip/wheels/92/f0/ac/2ba2972034e98971c3654ece337ac61e546bdeb34ca960dc8c
# Successfully built kaggle-cli cliff configparser PrettyTable pyperclip
# ...

# %%
# !kaggle competitions download -c bluebook-for-bulldozers -u santosh7
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 7, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api_extended.py", line 110, in authenticate
#     self._load_config(config_data)
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api_extended.py", line 149, in _load_config
#     raise ValueError('Error: Missing %s in configuration.' % item)
# ValueError: Error: Missing username in configuration.

# %%
# !kaggle config -g -u ‘santosh7’ -p ‘Kaggle2015’ -c ‘bluebook-for-bulldozers’
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 7, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api_extended.py", line 110, in authenticate
#     self._load_config(config_data)
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api_extended.py", line 149, in _load_config
#     raise ValueError('Error: Missing %s in configuration.' % item)
# ValueError: Error: Missing username in configuration.

# %%
# !pip install kaggle
# Out:
# ...
#     100% |████████████████████████████████| 61kB 4.2MB/s
# ...
#     100% |████████████████████████████████| 235kB 7.6MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/44/2c/df/22a6eeb780c36c28190faef6252b739fdc47145fd87a6642d4
# done
#   Stored in directory: /root/.cache/pip/wheels/e3/65/da/2045deea3098ed7471eca0e2460cfbd3fdfe8c1d6fa6fcac92
# Successfully built kaggle python-slugify
# ...

# %%
# !ls sample_data/
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# !kaggle competitions download -c bluebook-for-bulldozers
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 7, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api_extended.py", line 110, in authenticate
#     self._load_config(config_data)
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api_extended.py", line 149, in _load_config
#     raise ValueError('Error: Missing %s in configuration.' % item)
# ValueError: Error: Missing username in configuration.

# %%
cp /root/.kaggle-cli/config /root/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c bluebook-for-bulldozers
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 7, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api_extended.py", line 110, in authenticate
#     self._load_config(config_data)
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api_extended.py", line 149, in _load_config
#     raise ValueError('Error: Missing %s in configuration.' % item)
# ValueError: Error: Missing username in configuration.

# %%
# !head /root/.kaggle/kaggle.json
# Out:
# [user]
# username = ‘santosh7’
# password = ‘Kaggle2015’
# competition = ‘bluebook-for-bulldozers’

# %%
# !kaggle datasets list
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 7, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api_extended.py", line 110, in authenticate
#     self._load_config(config_data)
#   File "/usr/local/lib/python3.6/dist-packages/kaggle/api/kaggle_api_extended.py", line 149, in _load_config
#     raise ValueError('Error: Missing %s in configuration.' % item)
# ValueError: Error: Missing username in configuration.

# %%
# !head /content/.kaggle/kaggle.json
# Out:
# {"username": "santosh7", "key": "422fdad87a7bb7199b50f3807d828147"}

# %%
import json

# %%
token = {"username":"santosh7","key":"422fdad87a7bb7199b50f3807d828147"}

# %%
# !mkdir /content/.kaggle
# !touch /content/.kaggle/kaggle.json
with open("/content/.kaggle/kaggle.json", "w") as file:
  json.dump(token,file)
# Out:
# mkdir: cannot create directory ‘/content/.kaggle’: File exists

# %%
# !chmod 600 /content/.kaggle/kaggle.json
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c bluebook-for-bulldozers
# Out:
# ...
#  73% 5.00M/6.85M [00:00<00:00, 33.1MB/s]
# 100% 6.85M/6.85M [00:00<00:00, 43.0MB/s]
# ...
#  54% 5.00M/9.28M [00:00<00:00, 30.3MB/s]
# 100% 9.28M/9.28M [00:00<00:00, 50.5MB/s]
# ...
#   0% 0.00/209k [00:00<?, ?B/s]
# 100% 209k/209k [00:00<00:00, 75.3MB/s]
# ...
#   0% 0.00/3.17M [00:00<?, ?B/s]
# 100% 3.17M/3.17M [00:00<00:00, 170MB/s]
# ...
#   0% 0.00/297k [00:00<?, ?B/s]
# 100% 297k/297k [00:00<00:00, 149MB/s]
# ...
#   0% 0.00/10.8k [00:00<?, ?B/s]
# 100% 10.8k/10.8k [00:00<00:00, 13.4MB/s]
# ...
#   0% 0.00/192k [00:00<?, ?B/s]
# 100% 192k/192k [00:00<00:00, 64.4MB/s]
# ...
#  98% 48.0M/49.1M [00:00<00:00, 56.1MB/s]
# 100% 49.1M/49.1M [00:00<00:00, 138MB/s]
# ...
#   0% 0.00/316k [00:00<?, ?B/s]
# 100% 316k/316k [00:00<00:00, 124MB/s]
# ...
#  71% 5.00M/7.06M [00:00<00:00, 29.9MB/s]
# 100% 7.06M/7.06M [00:00<00:00, 39.3MB/s]
# ...
#  90% 103M/114M [00:00<00:00, 99.3MB/s]
# 100% 114M/114M [00:00<00:00, 134MB/s]
# ...
#  52% 5.00M/9.59M [00:00<00:00, 34.4MB/s]
# 100% 9.59M/9.59M [00:00<00:00, 58.4MB/s]
# ...
#   0% 0.00/3.40M [00:00<?, ?B/s]
# ...

# %%
# !ls
# Out:
# Data%20Dictionary.xlsx		  Test.csv	     Train.zip
# Machine_Appendix.csv		  Train.7z	     Valid.7z
# median_benchmark.csv		  TrainAndValid.7z   Valid.csv
# random_forest_benchmark_test.csv  TrainAndValid.csv  ValidSolution.csv
# sample_data			  TrainAndValid.zip  Valid.zip

# %%
# !pwd
# Out:
# /content

# %%
PATH = "~/content/"

# %%
# !gzip Train.zip

# %%
ls
# Out:
# Data%20Dictionary.xlsx            Test.csv           Train.zip.gz
# Machine_Appendix.csv              Train.7z.gz        Valid.7z
# median_benchmark.csv              TrainAndValid.7z   Valid.csv
# random_forest_benchmark_test.csv  TrainAndValid.csv  ValidSolution.csv
# sample_data/                      TrainAndValid.zip  Valid.zip

# %%
# !gunzip Train.zip.gz

# %%
# !ls
# Out:
# Data%20Dictionary.xlsx		  Test.csv	     Train.zip
# Machine_Appendix.csv		  Train.7z.gz	     Valid.7z
# median_benchmark.csv		  TrainAndValid.7z   Valid.csv
# random_forest_benchmark_test.csv  TrainAndValid.csv  ValidSolution.csv
# sample_data			  TrainAndValid.zip  Valid.zip

# %%
# !unzip Train.zip
# Out:
# Archive:  Train.zip
#   inflating: Train.csv

# %%
# !ls -ltr
# Out:
# total 322508
# -rw-r--r-- 1 root root 116403970 Jan 24  2013 Train.csv
# drwxr-xr-x 2 root root      4096 Sep 27 01:09 sample_data
# -rw-r--r-- 1 root root   7184626 Sep 27 23:10 Train.7z.gz
# -rw-r--r-- 1 root root   9732240 Sep 27 23:10 Train.zip
# -rw-r--r-- 1 root root    214480 Sep 27 23:10 Valid.7z
# -rw-r--r-- 1 root root   3318969 Sep 27 23:10 Valid.csv
# -rw-r--r-- 1 root root    303660 Sep 27 23:10 Valid.zip
# -rw-r--r-- 1 root root     11063 Sep 27 23:10 Data%20Dictionary.xlsx
# -rw-r--r-- 1 root root    196760 Sep 27 23:10 median_benchmark.csv
# -rw-r--r-- 1 root root  51498702 Sep 27 23:10 Machine_Appendix.csv
# -rw-r--r-- 1 root root    323524 Sep 27 23:10 ValidSolution.csv
# -rw-r--r-- 1 root root   7403772 Sep 27 23:10 TrainAndValid.7z
# -rw-r--r-- 1 root root 119791159 Sep 27 23:10 TrainAndValid.csv
# -rw-r--r-- 1 root root  10057248 Sep 27 23:10 TrainAndValid.zip
# -rw-r--r-- 1 root root   3560907 Sep 27 23:10 Test.csv
# ...

# %%
PATH = "/content/"
# !ls {PATH}
# Out:
# Data%20Dictionary.xlsx		  Train.7z.gz	     Valid.7z
# Machine_Appendix.csv		  TrainAndValid.7z   Valid.csv
# median_benchmark.csv		  TrainAndValid.csv  ValidSolution.csv
# random_forest_benchmark_test.csv  TrainAndValid.zip  Valid.zip
# sample_data			  Train.csv
# Test.csv			  Train.zip

# %%
ls
# Out:
# Data%20Dictionary.xlsx            Train.7z.gz        Valid.7z
# Machine_Appendix.csv              TrainAndValid.7z   Valid.csv
# median_benchmark.csv              TrainAndValid.csv  ValidSolution.csv
# random_forest_benchmark_test.csv  TrainAndValid.zip  Valid.zip
# sample_data/                      Train.csv
# Test.csv                          Train.zip

# %%
ls
# Out:
# Data%20Dictionary.xlsx            Train.7z.gz        Valid.7z
# Machine_Appendix.csv              TrainAndValid.7z   Valid.csv
# median_benchmark.csv              TrainAndValid.csv  ValidSolution.csv
# random_forest_benchmark_test.csv  TrainAndValid.zip  Valid.zip
# sample_data/                      Train.csv
# Test.csv                          Train.zip

# %%
pwd
# Out:
# '/content'

# %%
# !head Train.csv
# Out:
# SalesID,SalePrice,MachineID,ModelID,datasource,auctioneerID,YearMade,MachineHoursCurrentMeter,UsageBand,saledate,fiModelDesc,fiBaseModel,fiSecondaryDesc,fiModelSeries,fiModelDescriptor,ProductSize,fiProductClassDesc,state,ProductGroup,ProductGroupDesc,Drive_System,Enclosure,Forks,Pad_Type,Ride_Control,Stick,Transmission,Turbocharged,Blade_Extension,Blade_Width,Enclosure_Type,Engine_Horsepower,Hydraulics,Pushblock,Ripper,Scarifier,Tip_Control,Tire_Size,Coupler,Coupler_System,Grouser_Tracks,Hydraulics_Flow,Track_Type,Undercarriage_Pad_Width,Stick_Length,Thumb,Pattern_Changer,Grouser_Type,Backhoe_Mounting,Blade_Type,Travel_Controls,Differential_Type,Steering_Controls
# 1139246,66000,999089,3157,121,3,2004,68,Low,11/16/2006 0:00,521D,521,D,,,,Wheel Loader - 110.0 to 120.0 Horsepower,Alabama,WL,Wheel Loader,,EROPS w AC,None or Unspecified,,None or Unspecified,,,,,,,,2 Valve,,,,,None or Unspecified,None or Unspecified,,,,,,,,,,,,,Standard,Conventional
# ...

# %%
name = 'Santosh'
f'Hello {name}'
# Out:
# 'Hello Santosh'

# %%
df_raw= pd.read_csv(f'{PATH}Train.csv', low_memory=False, parse_dates=["saledate"])

# %%
df_raw
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 0       1139246      66000     999089     3157         121           3.0
# 1       1139248      57000     117657       77         121           3.0
# 2       1139249      10000     434808     7009         121           3.0
# 3       1139251      38500    1026470      332         121           3.0
# 4       1139253      11000    1057373    17311         121           3.0
# 5       1139255      26500    1001274     4605         121           3.0
# 6       1139256      21000     772701     1937         121           3.0
# 7       1139261      27000     902002     3539         121           3.0
# 8       1139272      21500    1036251    36003         121           3.0
# 9       1139275      65000    1016474     3883         121           3.0
# 10      1139278      24000    1024998     4605         121           3.0
# 11      1139282      22500     319906     5255         121           3.0
# ...

# %%
def display_all(df):
  with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000):
    display(df)

# %%
display_all(df_raw.tail().T)
# Out:
#                                                                      401120  \
# SalesID                                                             6333336
# SalePrice                                                             10500
# MachineID                                                           1840702
# ModelID                                                               21439
# datasource                                                              149
# auctioneerID                                                              1
# YearMade                                                               2005
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# saledate                                                2011-11-02 00:00:00
# fiModelDesc                                                           35NX2
# ...

# %%
df_raw.tail()
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 401120  6333336      10500    1840702    21439         149           1.0
# 401121  6333337      11000    1830472    21439         149           1.0
# 401122  6333338      11500    1887659    21439         149           1.0
# 401123  6333341       9000    1903570    21435         149           2.0
# 401124  6333342       7750    1926965    21435         149           2.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand   saledate  \
# 401120      2005                       NaN       NaN 2011-11-02
# 401121      2005                       NaN       NaN 2011-11-02
# 401122      2005                       NaN       NaN 2011-11-02
# 401123      2005                       NaN       NaN 2011-10-25
# 401124      2005                       NaN       NaN 2011-10-25
#
#               ...        Undercarriage_Pad_Width         Stick_Length  \
# ...
